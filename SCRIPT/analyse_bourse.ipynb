# %%
print("Analyse Bourse")
# Out:
# Analyse Bourse

# %% [markdown]
# # Let's go learning PYTHON !

# %%
# This is a comment in the code cell
# Python is OBJECT programming. We define variables.
name = "Mehmet Mikail"

print(name)
# Out:
# Mehmet Mikail

# %%
name
# Out:
# 'Mehmet Mikail'

# %%
age = 25
print(age)
# Out:
# 25

# %%
pi = 3.14159
pi
# Out:
# 3.14159

# %%
print(f'Hello, {name}')
# Out:
# Hello, Mehmet Mikail

# %%
is_cool = True
is_cool
# Out:
# True

# %% [markdown]
# # Presentation of the DATA STRUCTURES

# %%
stocks = ["AAPL","GOOGL","MSFT","TSLA"]

# %%
stocks
# Out:
# ['AAPL', 'GOOGL', 'MSFT', 'TSLA']

# %%
stocks.append("AMZN")
stocks
# Out:
# ['AAPL', 'GOOGL', 'MSFT', 'TSLA', 'AMZN']

# %%
prices = {
    "APPL":248.04,
    "GOOGL":328.33,
    "TSLA":437.43
}

# %%
prices
# Out:
# {'APPL': 248.04, 'GOOGL': 328.33, 'TSLA': 437.43}

# %% [markdown]
# # The key of success

# %%
# C'est le fait que Ptyhon repose sur des PACKAGES
# Donc on gagne un temps fou à ne pas ré inventer la ROUE à chaque fois
# ! pip install yfinance

# %%
# !pip install yfinance
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 76.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 78.6 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 65.7 MB/s  0:00:00
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15634 sha256=70758eb7c8a999a1ca1c54a2f16a5ac9a3e3b1f8948fda58057b6794a94924a4
#   Stored in directory: /home/codespace/.cache/pip/wheels/cc/bd/6f/664d62c99327abeef7d86489e6631cbf45b56fbf7ef1d6ef00
# Successfully built multitasking
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [yfinance]/10 [curl_cffi]]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import yfinance as yf
